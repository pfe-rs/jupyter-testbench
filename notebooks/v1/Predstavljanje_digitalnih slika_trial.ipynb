# %%
import skimage
from skimage import io

# %% [markdown]
# ## Učitavanje slike

# %%
image_e = io.imread('einstein.tif')
print(image_e.shape)
print(image_e.dtype)
# Out:
# (256, 256)
# uint8

# %%
image_c = io.imread('cartman.png')
print(image_c.shape)
print(image_c.dtype)
# Out:
# (275, 300, 4)
# uint8

# %% [markdown]
# ## Prikaz slike

# %%
# %matplotlib inline
from matplotlib import pyplot
from matplotlib.pyplot import *

# %%
imshow(image_e, cmap='gray')
axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
imshow(image_c)
axis('off')
# Out:
# (-0.5, 299.5, 274.5, -0.5)

# %% [markdown]
# ## Prikaz slike vmin vmax

# %%
f = imread('einstein_lowcontrast.tif')
print('Minimalna vrednost piksela:' + str(f.min()))
print('Maksimalna vrednost piksela:' + str(f.max()))

figure, imshow(f, vmin=0, vmax=255, cmap='gray')
axis('off')
show()
figure, imshow(f, cmap='gray')
axis('off')
# Out:
# Minimalna vrednost piksela:89
# Maksimalna vrednost piksela:166
# (-0.5, 799.5, 678.5, -0.5)

# %% [markdown]
# ## Čuvanje slike

# %%
image_e = imread('einstein.tif')

figure, imshow(image_e, vmin=0, vmax=255, cmap='gray')
axis('off')
show()

imsave('slika.png', image_e)
imsave('slika_map.png', image_e, cmap='gray')

# %% [markdown]
# ## Indeksiranje

# %%
# učitati sliku einstein.tif ili iskoristiti prethodnu promenljivu

# %%
# kreirati i prikazati mirror-ovanu sliku po horizontali

# %%
# kreirati i prikazati mirror-ovanu sliku po vertikali

# %%
# kreirati i prikazati sliku sa svakim drugim pikselom po obe ose (duplo manju sliku)

# %%
# kreirati i prikazati sliku koja sadrži samo deo gde je Ajnštajnova glava koordinate: redovi 75 do 150, kolone 95 do 160

# %% [markdown]
# ## Logičko indeksiranje

# %%
import scipy
from scipy import io

DATA =  scipy.io.loadmat(os.path.join(data_dir, 'einstein_mask.mat'))
backgroundMask = DATA['mask']>0

# %%
# učitati sliku einstein.tif u promenljivu image i primeniti logičku masku koja ima vrednost 1 na pozicijama koje treba zamaskirati
# Maskiranu sliku kreirati dodeljivanjem vrednost 128 gde je maska aktivna i novonastalu sliku sačuvati u promenljivi imageGrayBackground

imageGrayBackground = np.zeros(image.shape)
imageGrayBackground[:,:] = image
imageGrayBackground[backgroundMask] = 128

# %%
fig = figure(figsize=(12,4), dpi=200)

fig.add_subplot(1,3,1)
img = imshow(image, cmap='gray')
img.axes.get_xaxis().set_visible(False)
img.axes.get_yaxis().set_visible(False)

fig.add_subplot(1,3,2)
img = imshow(backgroundMask, cmap='gray')
img.axes.get_xaxis().set_visible(False)
img.axes.get_yaxis().set_visible(False)

fig.add_subplot(1,3,3)
img = imshow(imageGrayBackground, cmap='gray')
img.axes.get_xaxis().set_visible(False)
img.axes.get_yaxis().set_visible(False)
