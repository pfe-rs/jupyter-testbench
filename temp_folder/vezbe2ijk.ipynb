# %%
import numpy as np
import scipy
from scipy.fft import fft
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import signal

# %% [markdown]
# ## Vežbe za samostalan rad

# %% [markdown]
# ### Prvi zadatak
#
# Napraviti funkciju koja generiše tri sinusoide zadatih frekvencija $f_1$, $f_2$ i $f_3$ i amplituda $A_1$, $A_2$ i $A_3$
#
# Duzina signala treba da bude 3 sekunde, a frekvencija odabiranja ($f_s$) 10000

# %%
def zbirTriSinusoide(f1: float, f2: float, f3: float, A1: float, A2: float, A3: float, t: np.array) -> np.array:
    # Implementirati ovaj deo
    return signal

# Primer ulaznih podataka

duzina = 3
fs = 10000

f1 = 3
f2 = 5
f3 = 7

A1 = 3
A2 = 4
A3 = 0.5

t = np.linspace(0, duzina, duzina * fs)
x_zbir = zbirTriSinusoide(f1, f2, f3, A1, A2, A3, t)

mpl.rc('font', family = 'serif', size = 18)

fig, ax = plt.subplots(figsize = (10,8))
ax.set_xlabel("t")
ax.set_ylabel("x(t)")
plt.plot(t, x_zbir)

# %% [markdown]
# Napraviti funkciju koja skalira oformljeni signal sa koeficijentom K

# %%
def skaliranje_signala(signal: np.array, K: float) -> np.array:
    # Implementirati ovaj deo
    
    return y_skalirano

# Primer ulaznih podataka

K = 0.3
skalirani_signal = skaliranje_signala(signal, K)

plt.plot(t,signal)
plt.plot(t,skalirani_signal)
plt.show()
